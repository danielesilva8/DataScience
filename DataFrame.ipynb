# %% [markdown]
# <a href="https://colab.research.google.com/github/danielesilva8/Aula_DataScience/blob/master/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'Aluno' : ["Wilfred", "Abbie", "Harry", "Julia", "Carrie"],
                   'Faltas' : [3,4,2,1,4],
                   'Prova' : [2,7,5,10,6],
                   'Seminário' : [8.5,7.5,9.0,7.5,8.0]})
df
# Out:
#      Aluno  Faltas  Prova  Seminário
# 0  Wilfred       3      2        8.5
# 1    Abbie       4      7        7.5
# 2    Harry       2      5        9.0
# 3    Julia       1     10        7.5
# 4   Carrie       4      6        8.0

# %%
df.dtypes
# Out:
# Aluno         object
# Faltas         int64
# Prova          int64
# Seminário    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Aluno', 'Faltas', 'Prova', 'Seminário'], dtype='object')

# %%
df['Faltas']
# Out:
# 0    3
# 1    4
# 2    2
# 3    1
# 4    4
# Name: Faltas, dtype: int64

# %%
df.describe()
# Out:
#         Faltas      Prova  Seminário
# count  5.00000   5.000000    5.00000
# mean   2.80000   6.000000    8.10000
# std    1.30384   2.915476    0.65192
# min    1.00000   2.000000    7.50000
# 25%    2.00000   5.000000    7.50000
# 50%    3.00000   6.000000    8.00000
# 75%    4.00000   7.000000    8.50000
# max    4.00000  10.000000    9.00000

# %%
df.sort_values(by="Seminário")
# Out:
#      Aluno  Faltas  Prova  Seminário
# 1    Abbie       4      7        7.5
# 3    Julia       1     10        7.5
# 4   Carrie       4      6        8.0
# 0  Wilfred       3      2        8.5
# 2    Harry       2      5        9.0

# %%
df[df['Prova'] > 5]
# Out:
#     Aluno  Faltas  Prova  Seminário
# 1   Abbie       4      7        7.5
# 3   Julia       1     10        7.5
# 4  Carrie       4      6        8.0

# %%
df[(df['Seminário'] > 8.0) & (df['Prova']>3)]
# Out:
#    Aluno  Faltas  Prova  Seminário
# 2  Harry       2      5        9.0
